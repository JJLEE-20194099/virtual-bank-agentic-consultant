# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 33.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting scipy>=1.8.0
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 29.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 KB 45.4 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: numpy>=1.22.0 in /root/code/hackathon/virtual-bank-agentic-consultant/swin-env/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 scipy-1.15.3 threadpoolctl-3.6.0

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
df = pd.read_csv("/root/code/hackathon/virtual-bank-agentic-consultant/correct_trading_data.csv")
df
# Out:
#            transaction_id customer_id             datetime stock_code action  \
# 0         TC00001_0_BUY_0      C00001  2024-07-03 11:24:00        PVD    buy
# 1         TC00001_0_BUY_1      C00001  2024-07-03 14:07:00        SHB    buy
# 2         TC00001_0_BUY_2      C00001  2024-07-03 13:22:00        SHB    buy
# 3         TC00001_0_BUY_3      C00001  2024-07-03 11:25:00        PET    buy
# 4         TC00001_0_BUY_4      C00001  2024-07-03 10:42:00        VHC    buy
# ...                   ...         ...                  ...        ...    ...
# 439641   TC01000_48_BUY_2      C01000  2025-09-30 13:11:00        PVS    buy
# 439642   TC01000_48_BUY_3      C01000  2025-09-30 10:00:00        GMD    buy
# 439643   TC01000_48_BUY_4      C01000  2025-09-30 10:22:00        LPB    buy
# 439644  TC01000_49_SELL_0      C01000  2025-10-07 09:35:00        PDR   sell
# 439645   TC01000_49_BUY_1      C01000  2025-10-07 13:27:00        TCB    buy
#
#         quantity  price        fee
# 0             15  29.34   1.202270
# 1             79   7.93   2.735075
# 2             83   8.65   1.811411
# 3             77  30.18   9.235374
# 4             14  68.23   2.807521
# ...          ...    ...        ...
# 439641        37  29.72   2.060354
# 439642        37  67.90   4.572471
# 439643        50  49.50   8.586915
# 439644         8  22.75   0.578334
# 439645       109  39.00  13.290958
#
# [439646 rows x 8 columns]

# %%
with open("/root/code/hackathon/virtual-bank-agentic-consultant/backend/app/data/company/summary.json", "r", encoding="utf-8") as f:
    company_data = json.load(f)

def match_sector(symbol):
    return company_data[symbol]["sector"]
df["sector"] = df["stock_code"].apply(match_sector)
df["sector"].value_counts()
# Out:
# sector
# Real Estate               87011
# Banking                   83219
# Basic Materials           59434
# Industrials               50720
# Consumer Staples          43206
# Financial Services        31058
# Energy                    20946
# Retail                    14770
# Technology                10502
# Conglomerates             10195
# Utilities                  9104
# Consumer Discretionary     8957
# Insurance                  5879
# Communication Services     4645
# Name: count, dtype: int64

# %%
with open("/root/code/hackathon/virtual-bank-agentic-consultant/backend/app/data/customer/behaviour_labels.json", "r", encoding="utf-8") as f:
    trading_styles = json.load(f)

trading_style_df = pd.DataFrame()
trading_style_df["customer_id"] = trading_styles.keys()
trading_style_df["style"] = trading_styles.values()
trading_style_df
# Out:
#     customer_id       style
# 0        C00001  short_term
# 1        C00002  short_term
# 2        C00003       swing
# 3        C00004       swing
# 4        C00005       swing
# ..          ...         ...
# 995      C00996       swing
# 996      C00997   long_term
# 997      C00998  short_term
# 998      C00999       swing
# 999      C01000       swing
#
# [1000 rows x 2 columns]

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['total_value'] = df['quantity'] * df['price']

# %%
customer_df = df.groupby('customer_id').agg(
    total_trades=('transaction_id', 'count'),
    total_volume=('quantity', 'sum'),
    total_invested=('total_value', 'sum'),
    total_fees=('fee', 'sum'),
    unique_stocks=('stock_code', 'nunique'),
    last_transaction=('datetime', 'max')
).reset_index()
customer_df
# Out:
#     customer_id  total_trades  total_volume  total_invested   total_fees  \
# 0        C00001           961         75079      2150562.73  6457.673859
# 1        C00002          1038         83639      1765136.82  5449.519672
# 2        C00003           193         14282       549384.47  1546.373027
# 3        C00004           152          9805       573716.87  1681.607748
# 4        C00005           177         13349       370855.25  1105.123220
# ..          ...           ...           ...             ...          ...
# 995      C00996           165         11044       423141.40  1316.567883
# 996      C00997            15           892        27584.59    89.629812
# 997      C00998           951         72945      2211481.34  6449.281336
# 998      C00999           158         10447       326857.50   924.633564
# 999      C01000           178         11675       453137.76  1337.105104
#
#      unique_stocks    last_transaction
# 0               11 2025-10-07 14:40:00
# 1                6 2025-10-06 13:30:00
# 2               11 2025-10-03 14:41:00
# 3               13 2026-03-20 14:44:00
# 4               11 2025-10-06 14:21:00
# ..             ...                 ...
# 995             12 2025-10-02 14:31:00
# 996              4 2025-10-06 14:13:00
# 997             15 2025-10-08 14:11:00
# 998             10 2025-10-02 14:03:00
# 999             13 2025-10-07 13:27:00
#
# [1000 rows x 7 columns]

# %%
current_date = df['datetime'].max()
customer_df['recency'] = (current_date - customer_df['last_transaction']).dt.days

# %%
action_counts = df.pivot_table(index='customer_id', columns='action', values='transaction_id', aggfunc='count', fill_value=0)
customer_df['buy_ratio'] = list(action_counts['buy'] / (action_counts['buy'] + action_counts['sell']))
customer_df['buy_ratio'] = customer_df['buy_ratio'].fillna(0.5)
customer_df['buy_ratio']
# Out:
# 0      0.608741
# 1      0.633911
# 2      0.606218
# 3      0.559211
# 4      0.615819
#          ...
# 995    0.587879
# 996    0.866667
# 997    0.598318
# 998    0.670886
# 999    0.550562
# Name: buy_ratio, Length: 1000, dtype: float64

# %%
sector_pivot = df.pivot_table(index='customer_id', columns='sector', values='total_value', aggfunc='sum', fill_value=0)
sector_pct = sector_pivot.div(sector_pivot.sum(axis=1), axis=0)
sector_pct.columns = [f'pct_{col}' for col in sector_pct.columns]

final_df = pd.merge(customer_df, sector_pct, on='customer_id')

# %%
final_df.buy_ratio.value_counts()
# Out:
# buy_ratio
# 0.600000    17
# 0.666667    15
# 0.500000    14
# 0.625000    11
# 0.631579    10
#             ..
# 0.597727     1
# 0.628357     1
# 0.615142     1
# 0.564246     1
# 0.550562     1
# Name: count, Length: 713, dtype: int64

# %%
final_df = final_df.merge(trading_style_df, how='left', on = 'customer_id')
feature_df = final_df.drop(columns=['customer_id', 'last_transaction', 'style'])

# %%
cols_to_log = ['total_trades', 'total_volume', 'total_invested', 'total_fees']
for col in cols_to_log:
    feature_df[col] = np.log1p(feature_df[col])

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(feature_df)
scaled_features
# Out:
# array([[ 1.03108648,  1.03496919,  0.9230964 , ...,  0.20644579,
#         -0.37714502, -0.22735748],
#        [ 1.07996093,  1.09827639,  0.81164803, ..., -0.4350893 ,
#         -0.37714502, -0.22735748],
#        [ 0.01477366,  0.06192501,  0.15301559, ..., -0.4350893 ,
#         -0.37714502, -0.22735748],
#        ...,
#        [ 1.02445385,  1.01806182,  0.93885878, ..., -0.26000509,
#         -0.37714502,  0.69796151],
#        [-0.11150974, -0.12140392, -0.140006  , ..., -0.4350893 ,
#         -0.37714502, -0.22735748],
#        [-0.0363051 , -0.05624547,  0.04433186, ...,  0.13031587,
#          3.22780254, -0.22735748]])

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
final_df['cluster'] = kmeans.fit_predict(scaled_features)

# %%
cluster_analysis = final_df.groupby('cluster').mean(numeric_only=True)
print(cluster_analysis)
# Out:
#          total_trades  total_volume  total_invested   total_fees  \
# cluster
# 0           16.362903   1001.580645    3.519764e+04   104.267911
# 1          172.102210  11654.842541    3.952113e+05  1179.307417
# 2          957.146154  74045.933333    2.567890e+06  7707.529365
#
#          unique_stocks     recency  buy_ratio  pct_Banking  \
# cluster
# 0             3.020161  188.370968   0.646159     0.170210
# 1            12.287293  141.389503   0.608553     0.143629
# 2            11.387179   95.266667   0.604606     0.140105
#
#          pct_Basic Materials  pct_Communication Services  ...  \
# cluster                                                   ...
# 0                   0.127762                    0.011331  ...
# 1                   0.142376                    0.004633  ...
# 2                   0.149158                    0.004167  ...
#
#          pct_Consumer Discretionary  pct_Consumer Staples  pct_Energy  \
# cluster
# 0                          0.018382              0.093658    0.064378
# 1                          0.020507              0.112237    0.051779
# 2                          0.018896              0.118527    0.056069
#
#          pct_Financial Services  pct_Industrials  pct_Insurance  \
# cluster
# 0                      0.043245         0.125700       0.012318
# 1                      0.049738         0.134525       0.013651
# 2                      0.053475         0.122838       0.019639
#
#          pct_Real Estate  pct_Retail  pct_Technology  pct_Utilities
# cluster
# 0               0.206808    0.054008        0.041217       0.018790
# 1               0.185721    0.063958        0.051783       0.011469
# 2               0.188236    0.063542        0.043855       0.010206
#
# [3 rows x 21 columns]

# %%
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_features)
plt.figure(figsize=(10, 6))
sns.scatterplot(x=pca_data[:, 0], y=pca_data[:, 1], hue=final_df['cluster'], palette='viridis')
plt.title('PCA Vis')
plt.show()
